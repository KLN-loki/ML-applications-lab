# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('student.csv')
df.head()
# Out:
#    roll no    phone no  cgpa  age
# 0      531  6304733962  5.88   19
# 1      523  8985231234  5.40   20
# 2      537  7331672345  6.99   21
# 3      514  9873949806   NaN   20
# 4      589  7836784509  7.20   19

# %%
df.describe()
# Out:
#           roll no      phone no      cgpa        age
# count    6.000000  6.000000e+00  5.000000   6.000000
# mean   489.333333  7.349517e+09  6.534000  19.833333
# std    123.981719  2.155380e+09  0.837962   0.752773
# min    242.000000  3.764732e+09  5.400000  19.000000
# 25%    516.250000  6.561469e+09  5.880000  19.250000
# 50%    527.000000  7.584228e+09  6.990000  20.000000
# 75%    535.500000  8.698120e+09  7.200000  20.000000
# max    589.000000  9.873950e+09  7.200000  21.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   roll no   6 non-null      int64
#  1   phone no  6 non-null      int64
#  2   cgpa      5 non-null      float64
#  3   age       6 non-null      int64
# dtypes: float64(1), int64(3)
# memory usage: 324.0 bytes

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print('roll no')
print(df['roll no'].unique())
print('phone no')
print(df['phone no'].unique())
print('cgpa')
print(df['cgpa'].unique())
# Out:
# roll no
# [531 523 537 514 589 242]
# phone no
# [6304733962 8985231234 7331672345 9873949806 7836784509 3764732321]
# cgpa
# [5.88 5.4  6.99  nan 7.2 ]

# %%
sns.countplot(x='cgpa',data=df)
# Out:
# <Axes: xlabel='cgpa', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# roll no     0
# phone no    0
# cgpa        1
# age         0
# dtype: int64

# %%
df.cgpa.fillna(df['cgpa'].mean(),inplace=True)
print(df.isnull().sum())
# Out:
# roll no     0
# phone no    0
# cgpa        0
# age         0
# dtype: int64
# C:\Users\KLN\AppData\Local\Temp\ipykernel_2100\950915670.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.cgpa.fillna(df['cgpa'].mean(),inplace=True)

# %%
df.replace(np.nan,'0',inplace=True)
df.isnull().sum()
# Out:
# roll no     0
# phone no    0
# cgpa        0
# age         0
# dtype: int64

# %%
df.dtypes
# Out:
# roll no       int64
# phone no      int64
# cgpa        float64
# age           int64
# dtype: object

# %%
df[df['cgpa'] >= 6].head()
# Out:
#    roll no    phone no   cgpa  age
# 2      537  7331672345  6.990   21
# 3      514  9873949806  6.534   20
# 4      589  7836784509  7.200   19
# 5      242  3764732321  7.200   20

# %%
df[['cgpa']].boxplot()
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.hist(df['cgpa'])
plt.xlabel('cgpa')
plt.ylabel('count')
plt.title('cgpa distribution')
# Out:
# Text(0.5, 1.0, 'cgpa distribution')

# %%
plt.pie(df['roll no'].value_counts(), labels=df['cgpa'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1b7ae076ed0>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, '5.88'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, '5.4'),
#   Text(-0.9526279870751434, 0.5499999256737774, '6.99'),
#   Text(-0.952627884085708, -0.5500001040567056, '6.534000000000001'),
#   Text(1.5448414935947287e-07, -1.0999999999999892, '7.2'),
#   Text(0.9526280385698485, -0.5499998364823061, '7.2')])

# %%
plt.figure()
df['cgpa'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
plt.scatter(df['roll no'], df['cgpa'])
plt.xlabel('rollno')
plt.ylabel('cgpa')
plt.title('scatter plot')
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
sns.violinplot(y='cgpa',x='age', data=df, orient='vertical')
sns.violinplot(y='age',x='cgpa', data=df, orient='vertical')
# Out:
# <Axes: xlabel='age', ylabel='cgpa'>

# %%
def multivariate_eda(df):
    plt.figure(figsize=(3,4))
    sns.pairplot( df )
    plt.title('Multivariate EDA')
    # plt.show()
multivariate_eda(df)
